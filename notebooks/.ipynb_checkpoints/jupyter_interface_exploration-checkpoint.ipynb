# %% [markdown]
# M
# # Jupyter Interface Exploration
# ## Urban Transit Delay Analysis Project
# This notebook confirms that Jupyter Notebook launches correctly from the project folder and the Python kernel is active.

# %%
print("Jupyter Notebook is running correctly") 
print("Project: Urban Transit Delay Analysis") 
print("Environment: transit-analysis") 
print("Kernel: Python 3.11.15")
# Out:
# Jupyter Notebook is running correctly
# Project: Urban Transit Delay Analysis
# Environment: transit-analysis
# Kernel: Python 3.11.15
